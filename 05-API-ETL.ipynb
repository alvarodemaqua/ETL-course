# %% [markdown]
# *API y Generación de un ETL completo*
#
# Con todo lo aprendido hasta ahora, vamos a realizar una ETL completa, que cruce información diferente y produzca un resultado que vamos a almacenar en un CSV
#
# Para ello usaremos la API pública fiscaldata.treasury.gov para recuperar todos los cambios de monedas del mundo.

# %%
# Out:
# C:\Users\adema\AppData\Local\Temp\ipykernel_11192\499200561.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exchange_rates = exchange_rates.append({'country_currency': currency, 'exchange_rates': rate, 'record_date': record}, ignore_index=True)
# C:\Users\adema\AppData\Local\Temp\ipykernel_11192\499200561.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   exchange_rates = exchange_rates.append({'country_currency': currency, 'exchange_rates': rate, 'record_date': record}, ignore_index=True)
# C:\Users\adema\AppData\Local\Temp\ipykernel_11192\499200561.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# Utilizamos los métodos utilizados en el apartado de WebScrapping para recuperar el listado de los bancos y con mayor capitalización

# %%
# Out:
# C:\Users\adema\AppData\Local\Temp\ipykernel_11192\2207029951.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   banks = banks.append({'Name': name, 'Market Cap': market, 'Country': country}, ignore_index=True)
# C:\Users\adema\AppData\Local\Temp\ipykernel_11192\2207029951.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   banks = banks.append({'Name': name, 'Market Cap': market, 'Country': country}, ignore_index=True)
# C:\Users\adema\AppData\Local\Temp\ipykernel_11192\2207029951.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   banks = banks.append({'Name': name, 'Market Cap': market, 'Country': country}, ignore_index=True)
# ...

# %% [markdown]
# Comprobamos ambos Dataframes

# %%
# Out:
#                                        Name  Market Cap         Country
# 0                            JPMorgan Chase      368.78   United States
# 1   Industrial and Commercial Bank of China      295.65           China
# 2                           Bank of America      279.73   United States
# 3                               Wells Fargo      214.34   United States
# 4                   China Construction Bank      207.98           China
# 5                Agricultural Bank of China      181.49           China
# 6                         HSBC Holdings PLC      169.47  United Kingdom
# 7                            Citigroup Inc.      163.58   United States
# 8                             Bank of China      151.15           China
# 9                      China Merchants Bank      133.37           China
# 10                     Royal Bank of Canada      113.80          Canada
# 11                    Toronto-Dominion Bank      106.61          Canada
# ...

# %%
# Out:
#                           country_currency  exchange_rates record_date
# 0                      Afghanistan-Afghani          89.110  2022-12-31
# 1                              Albania-Lek         106.500  2022-12-31
# 2                            Algeria-Dinar         136.467  2022-12-31
# 3                            Angola-Kwanza         503.650  2022-12-31
# 4    Antigua & Barbuda-E. Caribbean Dollar           2.700  2022-12-31
# ..                                     ...             ...         ...
# 172                           Vietnam-Dong       23610.000  2022-12-31
# 173                     Western Samoa-Tala           2.607  2022-12-31
# 174                             Yemen-Rial         580.000  2022-12-31
# 175                      Zambia-New Kwacha          18.100  2022-12-31
# 176                          Zimbabwe-RTGS         654.660  2022-12-31
#
# [170 rows x 3 columns]

# %%
# Out:
#                                        Name  Market Cap         Country  \
# 0                            JPMorgan Chase      368.78   United States
# 1   Industrial and Commercial Bank of China      295.65           China
# 2                           Bank of America      279.73   United States
# 3                               Wells Fargo      214.34   United States
# 4                   China Construction Bank      207.98           China
# 5                Agricultural Bank of China      181.49           China
# 6                         HSBC Holdings PLC      169.47  United Kingdom
# 7                            Citigroup Inc.      163.58   United States
# 8                             Bank of China      151.15           China
# 9                      China Merchants Bank      133.37           China
# 10                     Royal Bank of Canada      113.80          Canada
# 11                    Toronto-Dominion Bank      106.61          Canada
# ...
